# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv("D:\\datapool\\cs-training.csv")

x = df_train.drop([u'Unnamed: 0', u'SeriousDlqin2yrs'] , axis = 1)
y_column = u'SeriousDlqin2yrs'
y = df_train[u'SeriousDlqin2yrs']

# %%
x["test_cat1"] = pd.Series(np.random.randint(0,5,size=150000)).apply(lambda x:str(x)+"_test")
x["test_cat2"] = pd.Series(np.random.randint(0,10,size=150000)).apply(lambda x:str(x)+"_test")
x["test_cat3"] = pd.Series(np.random.randint(0,20,size=150000)).apply(lambda x:str(x)+"_test")
x["test_U"] = y
x.loc[x["test_cat1"] == "0_test","test_cat1"] = np.nan
x.loc[x["test_cat2"] == "0_test","test_cat2"] = np.nan
x.loc[x["test_cat3"] == "0_test","test_cat3"] = np.nan

#x["test_cat1"].value_counts()

#print np.random.randint.__doc__

# %%
# %run D:\gitstore\fy_scorecard.py

ximu = fs_scorecard(x,y,event = 1,workpath = "./")

#ximu.get_woe_iv()

ximu.columns_bin_dict["NumberOfTime30-59DaysPastDueNotWorse"] = [-np.inf,0,np.inf]
ximu.columns_bin_dict["NumberOfTime60-89DaysPastDueNotWorse"] = [-np.inf,0,np.inf]
ximu.columns_bin_dict["NumberOfTimes90DaysLate"] = [-np.inf,0,np.inf]

ximu.get_woe_iv()

ximu.woe_t.head()
# Out:
# FY Scorecard ready!
# test_cat3 : too many values for discrete variables.
# <string>:82: RuntimeWarning: divide by zero encountered in log
# ./woe_t.xlsx  generated;
#  <name>.woe_t, <name>.iv_t available
#                                var_name           var_cat  cat_total_count  \
# 0  RevolvingUtilizationOfUnsecuredLines    (-inf, 0.0192]            30000
# 1  RevolvingUtilizationOfUnsecuredLines  (0.0192, 0.0832]            30000
# 2  RevolvingUtilizationOfUnsecuredLines   (0.0832, 0.271]            30000
# 3  RevolvingUtilizationOfUnsecuredLines    (0.271, 0.699]            30000
# 4  RevolvingUtilizationOfUnsecuredLines      (0.699, inf]            30000
# 0                                   age      (-inf, 39.0]            32004
# 1                                   age      (39.0, 48.0]            30540
# 2                                   age      (48.0, 56.0]            29040
# 3                                   age      (56.0, 65.0]            29817
# 4                                   age       (65.0, inf]            28599
# 0  NumberOfTime30-59DaysPastDueNotWorse       (-inf, 0.0]           126018
# 1  NumberOfTime30-59DaysPastDueNotWorse        (0.0, inf]            23982
# 0                             DebtRatio     (-inf, 0.134]            30000
# 1                             DebtRatio    (0.134, 0.287]            30000
# 2                             DebtRatio    (0.287, 0.468]            30000
# 3                             DebtRatio      (0.468, 4.0]            30109
# 4                             DebtRatio        (4.0, inf]            29891
# 0                         MonthlyIncome    (-inf, 3000.0]            25084
# 1                         MonthlyIncome  (3000.0, 4544.2]            23024
# 2                         MonthlyIncome  (4544.2, 6300.0]            24057
# 3                         MonthlyIncome  (6300.0, 9083.0]            24084
# 4                         MonthlyIncome     (9083.0, inf]            24020
# 5                         MonthlyIncome               nan            29731
# 0       NumberOfOpenCreditLinesAndLoans       (-inf, 4.0]            33659
# 1       NumberOfOpenCreditLinesAndLoans       (12.0, inf]            27684
# 2       NumberOfOpenCreditLinesAndLoans        (4.0, 6.0]            26545
# 3       NumberOfOpenCreditLinesAndLoans        (6.0, 9.0]            37162
# 4       NumberOfOpenCreditLinesAndLoans       (9.0, 12.0]            24950
# 0               NumberOfTimes90DaysLate       (-inf, 0.0]           141662
# 1               NumberOfTimes90DaysLate        (0.0, inf]             8338
# 0          NumberRealEstateLoansOrLines       (-inf, 1.0]           108526
# 1          NumberRealEstateLoansOrLines        (1.0, 2.0]            31522
# 2          NumberRealEstateLoansOrLines        (2.0, inf]             9952
# 0  NumberOfTime60-89DaysPastDueNotWorse       (-inf, 0.0]           142396
# 1  NumberOfTime60-89DaysPastDueNotWorse        (0.0, inf]             7604
# 0                    NumberOfDependents       (-inf, 1.0]           113218
# 1                    NumberOfDependents        (1.0, 2.0]            19522
# 2                    NumberOfDependents        (2.0, inf]            13336
# 3                    NumberOfDependents               nan             3924
# 0                             test_cat1            1_test            30086
# 1                             test_cat1            2_test            30215
# 2                             test_cat1            3_test            29876
# 3                             test_cat1            4_test            29856
# 4                             test_cat1               nan            29967
# 0                             test_cat2            1_test            15011
# 1                             test_cat2            2_test            15019
# 2                             test_cat2            3_test            14907
# 3                             test_cat2            4_test            15068
# 4                             test_cat2            5_test            15084
# 5                             test_cat2            6_test            15007
# 6                             test_cat2            7_test            15055
# 7                             test_cat2            8_test            14924
# 8                             test_cat2            9_test            14933
# 9                             test_cat2               nan            14992
# 0                                test_U                 0           139974
# 1                                test_U                 1            10026
#
#    pos_count  neg_count      p_ni  p_y_total      p_yi        woe  \
# 0        582      29418  0.210168    0.06684  0.058049  -1.286617
# 1        497      29503  0.210775    0.06684  0.049571  -1.447382
# 2        877      29123  0.208060    0.06684  0.087473  -0.866502
# 3       2107      27893  0.199273    0.06684  0.210154   0.053164
# 4       5963      24037  0.171725    0.06684  0.594754   1.242254
# 0       3370      28634  0.204567    0.06684  0.336126   0.496593
# 1       2565      27975  0.199859    0.06684  0.255835   0.246922
# 2       2077      26963  0.192629    0.06684  0.207161   0.072734
# 3       1324      28493  0.203559    0.06684  0.132057  -0.432726
# 4        690      27909  0.199387    0.06684  0.068821  -1.063738
# 0       5041     120977  0.864282    0.06684  0.502793  -0.541721
# 1       4985      18997  0.135718    0.06684  0.497207   1.298427
# 0       1830      28170  0.201252    0.06684  0.182525  -0.097667
# 1       1716      28284  0.202066    0.06684  0.171155  -0.166025
# 2       1853      28147  0.201087    0.06684  0.184819  -0.084360
# 3       2974      27135  0.193857    0.06684  0.296629   0.425358
# 4       1653      28238  0.201737    0.06684  0.164871  -0.201802
# 0       2277      22807  0.162937    0.06684  0.227110   0.332066
# 1       1979      21045  0.150349    0.06684  0.197387   0.272204
# 2       1687      22370  0.159815    0.06684  0.168263   0.051506
# 3       1332      22752  0.162544    0.06684  0.132855  -0.201697
# 4       1082      22938  0.163873    0.06684  0.107919  -0.417709
# 5       1669      28062  0.200480    0.06684  0.166467  -0.185917
# 0       3103      30556  0.218298    0.06684  0.309495   0.349083
# 1       1846      25838  0.184591    0.06684  0.184121  -0.002550
# 2       1573      24972  0.178405    0.06684  0.156892  -0.128496
# 3       2017      35145  0.251082    0.06684  0.201177  -0.221596
# 4       1487      23463  0.167624    0.06684  0.148314  -0.122389
# 0       6554     135108  0.965236    0.06684  0.653700  -0.389724
# 1       3472       4866  0.034764    0.06684  0.346300   2.298734
# 0       7420     101106  0.722320    0.06684  0.740076   0.024285
# 4  -0.015992                        -0.221596                      0.024285
#
#         age  DebtRatio  NumberOfDependents  MonthlyIncome  test_U  \
# 0  0.246922   0.425358            0.209307      -0.417709    10.0
# 1  0.246922  -0.097667           -0.078749       0.332066   -10.0
# 2  0.496593  -0.097667           -0.078749       0.272204   -10.0
# 3  0.496593  -0.097667           -0.078749       0.272204   -10.0
# 4  0.072734  -0.097667           -0.078749      -0.417709   -10.0
#
#    RevolvingUtilizationOfUnsecuredLines  test_cat2  \
# 0                              1.242254   0.029494
# 1                              1.242254  -0.041152
# 2                              0.053164   0.042879
# 3                             -0.866502   0.029494
# 4                              1.242254  -0.025096
#
#    NumberOfTime30-59DaysPastDueNotWorse  NumberOfTime60-89DaysPastDueNotWorse  \
# 0                              1.298427                             -0.288208
# 1                             -0.541721                             -0.288208
# 2                              1.298427                             -0.288208
# 3                             -0.541721                             -0.288208
# 4                              1.298427                             -0.288208
#
#    NumberOfTimes90DaysLate
# 0                -0.389724
# 1                -0.389724
# 2                 2.298734
# 3                -0.389724
# 4                -0.389724

# %%
ximu.columns_bin_dict['NumberOfTimes90DaysLate']
# Out:
# [-inf, 0, inf]

# %%
ximu.woe_t.var_cat
# Out:
# 0      (-inf, 0.0192]
# 1    (0.0192, 0.0832]
# 2     (0.0832, 0.271]
# 3      (0.271, 0.699]
# 4        (0.699, inf]
# 0        (-inf, 39.0]
# 1        (39.0, 48.0]
# 2        (48.0, 56.0]
# 3        (56.0, 65.0]
# 4         (65.0, inf]
# 0         (-inf, 3.0]
# 1         (12.0, inf]
# 2          (3.0, 6.0]
# 3          (6.0, 9.0]
# 4         (9.0, 12.0]
# 0       (-inf, 0.134]
# 1      (0.134, 0.287]
# 2      (0.287, 0.468]
# 3        (0.468, 4.0]
# 4          (4.0, inf]
# 0      (-inf, 3000.0]
# 1    (3000.0, 4544.2]
# 2    (4544.2, 6300.0]
# 3    (6300.0, 9083.0]
# 4       (9083.0, inf]
# 5                 nan
# 0         (-inf, 4.0]
# 1         (12.0, inf]
# 2          (4.0, 6.0]
# 3          (6.0, 9.0]
#            ...
# 4         (7.2, 10.8]
# 0         (-inf, 1.0]
# 1          (1.0, 2.0]
# 2          (2.0, inf]
# 0         (-inf, 2.4]
# 1         (10.2, inf]
# 2          (2.4, 4.8]
# 3          (4.8, 7.2]
# 4         (7.2, 10.2]
# 0         (-inf, 1.0]
# 1          (1.0, 2.0]
# 2          (2.0, inf]
# 3                 nan
# 0              1_test
# 1              2_test
# 2              3_test
# 3              4_test
# 4                 nan
# 0              1_test
# 1              2_test
# 2              3_test
# 3              4_test
# 4              5_test
# 5              6_test
# 6              7_test
# 7              8_test
# 8              9_test
# 9                 nan
# 0                   0
# 1                   1
# Name: var_cat, Length: 65, dtype: object

# %%
ximu.iv_t
# Out:
#                                var_name        iv
# 0                             DebtRatio  0.059488
# 1                         MonthlyIncome  0.070233
# 2                    NumberOfDependents  0.027233
# 3       NumberOfOpenCreditLinesAndLoans  0.048023
# 4  NumberOfTime30-59DaysPastDueNotWorse  0.665194
# 5  NumberOfTime60-89DaysPastDueNotWorse  0.572373
# 6               NumberOfTimes90DaysLate  0.837551
# 7          NumberRealEstateLoansOrLines  0.012091
# 8  RevolvingUtilizationOfUnsecuredLines  1.059619
# 9                                   age  0.250039
