# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv("D:\\datapool\\cs-training.csv")

x = df_train.drop([u'Unnamed: 0', u'SeriousDlqin2yrs'] , axis = 1)
y_column = u'SeriousDlqin2yrs'
y = df_train[u'SeriousDlqin2yrs']

# %%
# %run D:\gitstore\fy_scorecard.py

ximu = fs_scorecard(x,y,event = 1,workpath = "./")

ximu.get_woe_iv()
# Out:
# FY Scorecard ready!
# ./woe_t.xlsx  generated;
#  <name>.woe_t, <name>.iv_t available

# %%
ximu.columns_bin_dict["NumberOfTime30-59DaysPastDueNotWorse"] = [-np.inf,0,np.inf]
ximu.columns_bin_dict["NumberOfTime60-89DaysPastDueNotWorse"] = [-np.inf,0,np.inf]
ximu.columns_bin_dict["NumberOfTimes90DaysLate"] = [-np.inf,0,np.inf]

ximu.get_woe_iv()
# Out:
# ./woe_t.xlsx  generated;
#  <name>.woe_t, <name>.iv_t available

# %%
ximu.woe_t
# Out:
#                                var_name           var_cat  cat_total_count  \
# 0  RevolvingUtilizationOfUnsecuredLines    (-inf, 0.0192]            30000
# 1  RevolvingUtilizationOfUnsecuredLines  (0.0192, 0.0832]            30000
# 2  RevolvingUtilizationOfUnsecuredLines   (0.0832, 0.271]            30000
# 3  RevolvingUtilizationOfUnsecuredLines    (0.271, 0.699]            30000
# 4  RevolvingUtilizationOfUnsecuredLines      (0.699, inf]            30000
# 0                                   age      (-inf, 39.0]            32004
# 1                                   age      (39.0, 48.0]            30540
# 2                                   age      (48.0, 56.0]            29040
# 3                                   age      (56.0, 65.0]            29817
# 4                                   age       (65.0, inf]            28599
# 0  NumberOfTime30-59DaysPastDueNotWorse       (-inf, 0.0]           126018
# 1  NumberOfTime30-59DaysPastDueNotWorse        (0.0, inf]            23982
# 0                             DebtRatio     (-inf, 0.134]            30000
# 1                             DebtRatio    (0.134, 0.287]            30000
# 2                             DebtRatio    (0.287, 0.468]            30000
# 3                             DebtRatio      (0.468, 4.0]            30109
# 4                             DebtRatio        (4.0, inf]            29891
# 0                         MonthlyIncome    (-inf, 3000.0]            25084
# 1                         MonthlyIncome  (3000.0, 4544.2]            23024
# 2                         MonthlyIncome  (4544.2, 6300.0]            24057
# 3                         MonthlyIncome  (6300.0, 9083.0]            24084
# 4                         MonthlyIncome     (9083.0, inf]            24020
# 5                         MonthlyIncome               nan            29731
# 0       NumberOfOpenCreditLinesAndLoans       (-inf, 4.0]            33659
# 1       NumberOfOpenCreditLinesAndLoans       (12.0, inf]            27684
# 2       NumberOfOpenCreditLinesAndLoans        (4.0, 6.0]            26545
# 3       NumberOfOpenCreditLinesAndLoans        (6.0, 9.0]            37162
# 4       NumberOfOpenCreditLinesAndLoans       (9.0, 12.0]            24950
# 0               NumberOfTimes90DaysLate       (-inf, 0.0]           141662
# 1               NumberOfTimes90DaysLate        (0.0, inf]             8338
# 0          NumberRealEstateLoansOrLines       (-inf, 1.0]           108526
# 1          NumberRealEstateLoansOrLines        (1.0, 2.0]            31522
# 2          NumberRealEstateLoansOrLines        (2.0, inf]             9952
# 0  NumberOfTime60-89DaysPastDueNotWorse       (-inf, 0.0]           142396
# 1  NumberOfTime60-89DaysPastDueNotWorse        (0.0, inf]             7604
# 0                    NumberOfDependents       (-inf, 1.0]           113218
# 1                    NumberOfDependents        (1.0, 2.0]            19522
# 2                    NumberOfDependents        (2.0, inf]            13336
# 3                    NumberOfDependents               nan             3924
#
#    pos_count  neg_count      p_ni  p_y_total      p_yi       woe      iv_i
# 0        582      29418  0.210168    0.06684  0.058049 -1.286617  0.195718
# 1        497      29503  0.210775    0.06684  0.049571 -1.447382  0.233323
# 2        877      29123  0.208060    0.06684  0.087473 -0.866502  0.104489
# 3       2107      27893  0.199273    0.06684  0.210154  0.053164  0.000578
# 4       5963      24037  0.171725    0.06684  0.594754  1.242254  0.525509
# 0       3370      28634  0.204567    0.06684  0.336126  0.496593  0.065332
# 1       2565      27975  0.199859    0.06684  0.255835  0.246922  0.013822
# 2       2077      26963  0.192629    0.06684  0.207161  0.072734  0.001057
# 3       1324      28493  0.203559    0.06684  0.132057 -0.432726  0.030941
# 4        690      27909  0.199387    0.06684  0.068821 -1.063738  0.138888
# 0       5041     120977  0.864282    0.06684  0.502793 -0.541721  0.195826
# 1       4985      18997  0.135718    0.06684  0.497207  1.298427  0.469367
# 0       1830      28170  0.201252    0.06684  0.182525 -0.097667  0.001829
# 1       1716      28284  0.202066    0.06684  0.171155 -0.166025  0.005132
# 2       1853      28147  0.201087    0.06684  0.184819 -0.084360  0.001372
# 3       2974      27135  0.193857    0.06684  0.296629  0.425358  0.043715
# 4       1653      28238  0.201737    0.06684  0.164871 -0.201802  0.007440
# 0       2277      22807  0.162937    0.06684  0.227110  0.332066  0.021309
# 1       1979      21045  0.150349    0.06684  0.197387  0.272204  0.012804
# 2       1687      22370  0.159815    0.06684  0.168263  0.051506  0.000435
# 3       1332      22752  0.162544    0.06684  0.132855 -0.201697  0.005988
# 4       1082      22938  0.163873    0.06684  0.107919 -0.417709  0.023372
# 5       1669      28062  0.200480    0.06684  0.166467 -0.185917  0.006324
# 0       3103      30556  0.218298    0.06684  0.309495  0.349083  0.031836
# 1       1846      25838  0.184591    0.06684  0.184121 -0.002550  0.000001
# 2       1573      24972  0.178405    0.06684  0.156892 -0.128496  0.002764
# 3       2017      35145  0.251082    0.06684  0.201177 -0.221596  0.011059
# 4       1487      23463  0.167624    0.06684  0.148314 -0.122389  0.002363
# 0       6554     135108  0.965236    0.06684  0.653700 -0.389724  0.121413
# 1       3472       4866  0.034764    0.06684  0.346300  2.298734  0.716138
# 0       7420     101106  0.722320    0.06684  0.740076  0.024285  0.000431
# 1       1765      29757  0.212589    0.06684  0.176042 -0.188639  0.006894
# 2        841       9111  0.065091    0.06684  0.083882  0.253629  0.004766
# 0       7256     135140  0.965465    0.06684  0.723718 -0.288208  0.069673
# 1       2770       4834  0.034535    0.06684  0.276282  2.079448  0.502700
# 0       7030     106188  0.758627    0.06684  0.701177 -0.078749  0.004524
# 1       1584      17938  0.128152    0.06684  0.157989  0.209307  0.006245
# 2       1233      12103  0.086466    0.06684  0.122980  0.352272  0.012863
# 3        179       3745  0.026755    0.06684  0.017854 -0.404516  0.003601
